# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# The class for plotting

class plot_diagram():
    
    # Constructor
    def __init__(self, X, Y, w, stop, go = False):
        start = w.data
        self.error = []
        self.parameter = []
        self.X = X.numpy()
        self.Y = Y.numpy()
        self.parameter_values = torch.arange(start, stop)
        self.Loss_function = [criterion(forward(X), Y) for w.data in self.parameter_values] 
        w.data = start
        
    # Executor
    def __call__(self, Yhat, w, error, n):
        self.error.append(error)
        self.parameter.append(w.data)
        plt.subplot(212)
        plt.plot(self.X, Yhat.detach().numpy())
        plt.plot(self.X, self.Y,'ro')
        plt.xlabel("A")
        plt.ylim(-20, 20)
        plt.subplot(211)
        plt.title("Data Space (top) Estimated Line (bottom) Iteration " + str(n))
        plt.plot(self.parameter_values.numpy(), self.Loss_function)   
        plt.plot(self.parameter, self.error, 'ro')
        plt.xlabel("B")
        plt.figure()
    
    # Destructor
    def __del__(self):
        plt.close('all')

# %% [markdown]
# # Data prepration

# %%
import torch

# %%
X = torch.arange(-3, 3, 0.1).view(-1, 1)
f = -3 * X

# %%
plt.plot(X.numpy(), f.numpy(), label = 'f')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
# add noise to data
Y1 = f + 0.1 * (torch.randn(X.size()))
Y2 = f + 2 * (torch.randn(X.size()))

# %%
plt.plot(X.numpy(), Y1.numpy(), 'rx' ,label = 'Y')
plt.plot(X.numpy(), f.numpy(), label = 'f')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# # Create the Model and Cost Function

# %% [markdown]
# <code>forward</code> function $y=w*x$

# %%
def forward(x):
    return w * x

# %%
def criterion(yhat, y):
    return torch.mean((yhat - y) ** 2)

# %%
lr = 0.1 # learning rate
LOSS = []

# %%
w = torch.tensor(-10.0, requires_grad = True)

# %%
gradient_plot = plot_diagram(X, Y, w, stop = 5)

# %% [markdown]
# # Train the Model

# %%
def train_model(iter):
    for epoch in range(iter):
        # make prediction
        Yhat = forward(X)
        # calculate loss of iteration
        loss = criterion(Yhat, Y)
        # plot diagram 
        gradient_plot(Yhat, w, loss.item(), epoch)
        # store loss
        LOSS.append(loss.item())
        # backward pass: compute gradient of the loss with respect to all the learnable parameters
        loss.backward()
        # update parameters
        w.data = w.data - lr * w.grad.data
        # zero the gradients before running the backward pass
        w.grad.data.zero_()

# %%
train_model(4)

# %%
plt.plot(LOSS)
plt.tight_layout()
plt.xlabel("Epoch/Iterations")
plt.ylabel("Cost")
# Out:
# Text(23.875, 0.5, 'Cost')

# %%
w = torch.tensor(-15.0, requires_grad = True)
LOSS2 = []
gradient_plot2 = plot_diagram(X, Y, w, stop = 15)

# %%
def train_model2(iter):
    for epoch in range(iter):
        # make prediction
        Yhat = forward(X)
        # calculate loss of iteration
        loss2 = criterion(Yhat, Y)
        # plot diagram 
        gradient_plot2(Yhat, w, loss2.item(), epoch)
        # store loss
        LOSS2.append(loss2.item())
        # backward pass: compute gradient of the loss with respect to all the learnable parameters
        loss2.backward()
        # update parameters
        w.data = w.data - lr * w.grad.data
        # zero the gradients before running the backward pass
        w.grad.data.zero_()

# %%
train_model2(4)

# %%
plt.plot(LOSS, label = "LOSS")
plt.plot(LOSS2, label = "LOSS2")
plt.tight_layout()
plt.xlabel("Epoch/Iterations")
plt.ylabel("Cost")
plt.legend()
